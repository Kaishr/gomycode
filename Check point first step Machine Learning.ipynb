# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures

# %%
data=pd.read_csv('C:/Users/kaism/Desktop/csv/kc_house_data.csv')
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
# correlation matrix
corr=data.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_cc8aaca8_557c_11eb_b050_0c5b8f279a64row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_cc8aaca8_557c_11eb_b050_0c5b8f279a64row0_col1 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_cc8aaca8_557c_11eb_b050_0c5b8f279a64row0_col2 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_cc8aaca8_557c_11eb_b050_0c5b8f279a64row0_col3 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_cc8aaca8_557c_11eb_b050_0c5b8f279a64row0_col4 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_cc8aaca8_557c_11eb_b050_0c5b8f279a64row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cc8aaca8_557c_11eb_b050_0c5b8f279a64row0_col6 {
#             background-color:  #84a7fc;
#             color:  #000000;
# ...

# %% [raw]
# # as we see in correlation matrix the price is correlated with sqft_living and grade

# %% [markdown]
# # Linear regression

# %%
#extract X and Y from data 
x=data["sqft_living"].values[:,np.newaxis]
y=data["price"].values

# %%
#Split your dataset into a training set and a testing set. 
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40)

# %%
#Apply Linear regression to your training set. 
model=LinearRegression()   
model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#Plot the linear regression.
plt.scatter(x_train,y_train,color='r')
plt.title('Linear regression')
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(x_train,model.predict(x_train),color='k')
plt.show()

# %%
#Measure the performance of linear regression using the testing set. 
predicted=model.predict(x_test)
print("MSE",mean_squared_error(y_test,predicted))
print("R Squared",metrics.r2_score(y_test,predicted))
# Out:
# MSE 62902408306.86502
# R Squared 0.4996528488387417

# %% [raw]
# # R Squared=0.49 means that half of the variance in the outcome variable is explained by the model.

# %%
# multi-linear regression
X=data[["sqft_living","grade"]]
Y=data["price"].values
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.35,random_state=40)
model=LinearRegression()
model.fit(X_train,Y_train)
predicted1=model.predict(X_test)
print("MSE",mean_squared_error(Y_test,predicted1))
print("R Squared",metrics.r2_score(Y_test,predicted1))
# Out:
# MSE 57413775762.86427
# R Squared 0.5433112989852685

# %% [raw]
# #Muli linear regression is better than linear regression because its Mean squared error is lower
# than Mean squared error of linear regression and because its R Squared is higher than linear regression one.

# %%
#Polynomial regression
poly=PolynomialFeatures(degree=2)
X_train_fit=poly.fit_transform(X_train)
lg=LinearRegression()
lg.fit(X_train_fit,Y_train)
X_test_fit=poly.fit_transform(X_test)
predicted2=lg.predict(X_test_fit)
print("MSE",mean_squared_error(Y_test,predicted2))
print("R Squared",metrics.r2_score(Y_test,predicted2))
# Out:
# MSE 50394480701.174934
# R Squared 0.5991451594337126

# %% [raw]
# #Polynomial regression is better than Muli-linear regression because its Mean squared error is lower
# than Mean squared error of Muli-linear regression and because its R Squared is higher than Muli-linear regression one.
